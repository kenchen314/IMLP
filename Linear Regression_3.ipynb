# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 3. Nonlinear
#
# $$f(x) = \sin(3.2x) + 0.8x$$

# %% [markdown]
# ### 3. 生成假資料

# %%
x = np.linspace(0, 5, 100)
y = np.sin(3.2*x) + 0.8*x + 0.3*np.random.randn(100)

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# #### nonlinear

# %%
regr_lin = LinearRegression()

# %%
X = x.reshape(-1, 1)
print(X.shape)
# Out:
# (100, 1)

# %%
regr_lin.fit(X,y)
# Out:
# LinearRegression()

# %%
Y=regr_lin.predict(X)
plt.scatter(x,y)
plt.plot(x,Y , color='r')
mse = np.sum((Y-y)**2) / len(y)
print(mse)
plt.show()
# Out:
# 0.4793995621112784

# %% [markdown]
# 果然超級不準, 該如何是好?

# %% [markdown]
# #### 多項式
#
# 多項式5次方

# %% [markdown]
# $$\widehat{y}=xw+b=w_{1}x_{1}+w_{2}x_{1}^{2}+w_{3}x_{1}^{3}+w_{4}x_{1}^{4}+w_{5}x_{1}^{5}+b$$

# %%
print(x.shape)
# Out:
# (100,)

# %%
X_poly = np.array([[k, k**2, k**3, k**4, k**5] for k in x])  # add k**6 to try it
print(X_poly.shape)
# Out:
# (100, 5)

# %%
regr_poly = LinearRegression()

# %%
regr_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_poly.predict(X_poly), 'r')
plt.show()

# %%
print('Coefficients: ', regr_poly.coef_)
print('interception: ', regr_poly.intercept_)
# Out:
# Coefficients:  [-0.79748151  1.21406672 -0.55627046  0.12900098 -0.01094171]
# interception:  0.9319860963944713

# %%
W=regr_poly.coef_
b=regr_poly.intercept_
np.dot(X_poly,W.T)+b
# Out:
# array([0.9319861 , 0.89473522, 0.8632596 , 0.83715893, 0.81605221,
#        0.79957726, 0.78739035, 0.77916569, 0.7745951 , 0.77338748,
#        0.77526845, 0.77997987, 0.78727944, 0.79694027, 0.80875041,
#        0.82251247, 0.83804314, 0.8551728 , 0.87374506, 0.89361635,
#        0.91465546, 0.93674316, 0.95977168, 0.98364439, 1.00827528,
#        1.03358857, 1.05951826, 1.08600771, 1.11300922, 1.14048356,
#        1.1683996 , 1.19673379, 1.22546983, 1.25459816, 1.28411557,
#        1.31402474, 1.34433383, 1.37505607, 1.40620925, 1.43781539,
#        1.46990023, 1.50249283, 1.53562515, 1.56933158, 1.60364855,
#        1.63861408, 1.67426734, 1.71064824, 1.74779699, 1.78575364,
#        1.8245577 , 1.86424767, 1.90486062, 1.94643178, 1.98899405,
#        2.03257764, 2.07720958, 2.12291335, 2.16970837, 2.21760963,
#        2.26662724, 2.31676601, 2.36802497, 2.42039701, 2.4738684 ,
#        2.52841837, 2.58401868, 2.6406332 , 2.69821746, 2.75671821,
#        2.81607304, 2.87620988, 2.93704662, 2.99849065, 3.06043845,
#        3.12277515, 3.18537407, 3.24809634, 3.31079043, 3.37329174,
#        3.43542215, 3.49698962, 3.5577877 , 3.61759518, 3.67617557,
#        3.73327675, 3.78863047, 3.84195199, 3.89293955, 3.94127406,
#        3.98661856, 4.02861785, 4.06689805, 4.10106615, 4.13070959,
#        4.15539584, 4.17467193, 4.18806408, 4.1950772 , 4.19519452])

# %%
regr_poly.predict(X_poly)
# Out:
# array([0.88285626, 0.86112702, 0.84381738, 0.83061887, 0.8212375 ,
#        0.81539355, 0.81282117, 0.8132681 , 0.81649541, 0.82227709,
#        0.83039986, 0.84066275, 0.85287687, 0.86686504, 0.88246155,
#        0.89951178, 0.91787193, 0.93740872, 0.95799903, 0.97952966,
#        1.00189695, 1.02500653, 1.04877297, 1.0731195 , 1.09797767,
#        1.12328708, 1.14899501, 1.17505619, 1.20143243, 1.22809232,
#        1.25501095, 1.28216956, 1.30955527, 1.33716073, 1.36498385,
#        1.39302747, 1.42129905, 1.44981037, 1.47857719, 1.507619  ,
#        1.53695866, 1.56662209, 1.59663801, 1.62703756, 1.65785407,
#        1.68912267, 1.72088003, 1.75316405, 1.78601354, 1.8194679 ,
#        1.85356682, 1.88834998, 1.92385673, 1.96012578, 1.99719491,
#        2.03510061, 2.07387784, 2.11355965, 2.15417695, 2.19575812,
#        2.23832874, 2.2819113 , 2.32652484, 2.3721847 , 2.41890214,
#        2.46668411, 2.51553288, 2.56544574, 2.61641472, 2.66842625,
#        2.72146088, 2.77549293, 2.83049023, 2.88641374, 2.94321735,
#        3.00084744, 3.05924267, 3.11833365, 3.17804258, 3.238283  ,
#        3.29895945, 3.35996718, 3.42119183, 3.48250909, 3.54378446,
#        3.60487288, 3.66561845, 3.72585409, 3.78540128, 3.84406972,
#        3.901657  , 3.95794835, 4.01271626, 4.06572024, 4.11670644,
#        4.1654074 , 4.21154172, 4.25481372, 4.2949132 , 4.33151506])

# %% [markdown]
# #### RBF
#
# $$\phi_i = e^{-\| x - c_i \|^2/2\sigma^2}$$

# %%
# normal distrubution
def RBF(x, center, sigma):
    k = np.exp(-(x - center)**2/(2*sigma**2))
    return k

# %%
sigma = 0.3

# %%
X_rbf = np.array([[RBF(k, .5, sigma), 
                  RBF(k, 1.5, sigma),
                  RBF(k, 2.5, sigma),
                  RBF(k, 3.5, sigma),
                  RBF(k, 4.5, sigma)] for k in x])

# %%
regr_rbf = LinearRegression()

# %%
regr_rbf.fit(X_rbf, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, regr_rbf.predict(X_rbf), 'r')
plt.show()

# %%
print('Coefficients: ', regr_rbf.coef_)
print('interception: ', regr_rbf.intercept_)
# Out:
# Coefficients:  [-0.92743899 -1.81612645  0.89633578  0.24664286  3.12929429]
# interception:  1.8884848359422168

# %% [markdown]
# #### Comparison

# %%
Y_lin = regr_lin.predict(X)
Y_poly = regr_poly.predict(X_poly)
Y_rbf = regr_rbf.predict(X_rbf)

# %%
plt.scatter(x,y)
plt.plot(x, Y_lin, label='linear')
plt.plot(x, Y_poly, label='polynomial')
plt.plot(x, Y_rbf, label='rbf')
plt.legend()
plt.show()

# %% [markdown]
# ## 請計算模型的MSE

# %%
print(np.sum((regr_lin.predict(X)-y)**2) / len(y))
# Out:
# 0.4793995621112784

# %%
print(np.sum((regr_poly.predict(X_poly)-y)**2) / len(y))
# Out:
# 0.41376447765536745

# %%
print(np.sum((regr_rbf.predict(X_rbf)-y)**2) / len(y))
# Out:
# 0.2145606289713619
